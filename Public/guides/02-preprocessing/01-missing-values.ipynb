# %% [markdown]
# # Missing Values

# %%
import pandas as pd
import os
import missingno

# %%
os.getcwd()
os.chdir("/Users/dinocuric/Documents/Datasets")

# %%
df = pd.read_csv("customers-withNA.csv", delimiter=";")
df
# Out:
#     customer_id                 name                        address  \
# 0          1980    Leocadia Andersen         7015 Fairground Street
# 1          2463          Chad Lucero            142 Wakehurst Drive
# 2          1978        Stone Randall           898 Peninsula Circle
# 3          9383         Emelia Braun            101 Military Street
# 4          8940         Ridley Velez           280 Pennington Drive
# 5          8940         Ridley Velez           280 Pennington Drive
# 6          2512        Devadas Sloan          8906 East John Street
# 7          1928       Jamaal Proctor                   374 New Lane
# 8          4524          Reba Morris             755 Hanover Street
# 9          9886        Nomusa Knight                            NaN
# 10         9815       Romaine Dunlap                  72 1st Street
# 11         7571         Regan Wilcox               55 Brewery Drive
# 12         1980        Forest Grimes       306 South Peninsula Road
# ...

# %% [markdown]
# ## Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  29 non-null     int64
#  1   name         28 non-null     object
#  2   address      28 non-null     object
#  3   city         28 non-null     object
#  4   state        29 non-null     object
#  5   zipcode      26 non-null     float64
#  6   country      29 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Sum of NAs

# %%
df.isnull().sum()
# Out:
# customer_id    0
# name           1
# address        1
# city           1
# state          0
# zipcode        3
# country        0
# dtype: int64

# %% [markdown]
# ## Visualize NAs

# %%
missingno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.dropna() # Dropped 6 rows
# Out:
#     customer_id                 name                        address  \
# 0          1980    Leocadia Andersen         7015 Fairground Street
# 1          2463          Chad Lucero            142 Wakehurst Drive
# 2          1978        Stone Randall           898 Peninsula Circle
# 3          9383         Emelia Braun            101 Military Street
# 4          8940         Ridley Velez           280 Pennington Drive
# 5          8940         Ridley Velez           280 Pennington Drive
# 6          2512        Devadas Sloan          8906 East John Street
# 7          1928       Jamaal Proctor                   374 New Lane
# 8          4524          Reba Morris             755 Hanover Street
# 10         9815       Romaine Dunlap                  72 1st Street
# 11         7571         Regan Wilcox               55 Brewery Drive
# 13          335  Feliciana Gillespie          62 Old Carriage Drive
# 14         4687           Ella Logan             8758 Chapel Street
# ...

# %% [markdown]
# ## Drop NAs

# %%
df_mod = df.dropna().copy()
df_mod
# Out:
#     customer_id                 name                        address  \
# 0          1980    Leocadia Andersen         7015 Fairground Street
# 1          2463          Chad Lucero            142 Wakehurst Drive
# 2          1978        Stone Randall           898 Peninsula Circle
# 3          9383         Emelia Braun            101 Military Street
# 4          8940         Ridley Velez           280 Pennington Drive
# 5          8940         Ridley Velez           280 Pennington Drive
# 6          2512        Devadas Sloan          8906 East John Street
# 7          1928       Jamaal Proctor                   374 New Lane
# 8          4524          Reba Morris             755 Hanover Street
# 10         9815       Romaine Dunlap                  72 1st Street
# 11         7571         Regan Wilcox               55 Brewery Drive
# 13          335  Feliciana Gillespie          62 Old Carriage Drive
# 14         4687           Ella Logan             8758 Chapel Street
# ...

# %% [markdown]
# Original is unchanged.

# %%
df
# Out:
#     customer_id                 name                        address  \
# 0          1980    Leocadia Andersen         7015 Fairground Street
# 1          2463          Chad Lucero            142 Wakehurst Drive
# 2          1978        Stone Randall           898 Peninsula Circle
# 3          9383         Emelia Braun            101 Military Street
# 4          8940         Ridley Velez           280 Pennington Drive
# 5          8940         Ridley Velez           280 Pennington Drive
# 6          2512        Devadas Sloan          8906 East John Street
# 7          1928       Jamaal Proctor                   374 New Lane
# 8          4524          Reba Morris             755 Hanover Street
# 9          9886        Nomusa Knight                            NaN
# 10         9815       Romaine Dunlap                  72 1st Street
# 11         7571         Regan Wilcox               55 Brewery Drive
# 12         1980        Forest Grimes       306 South Peninsula Road
# ...

# %% [markdown]
# ## Fill NAs

# %%
df.city = df.city.fillna("New York City")
df
# Out:
#     customer_id                 name                        address  \
# 0          1980    Leocadia Andersen         7015 Fairground Street
# 1          2463          Chad Lucero            142 Wakehurst Drive
# 2          1978        Stone Randall           898 Peninsula Circle
# 3          9383         Emelia Braun            101 Military Street
# 4          8940         Ridley Velez           280 Pennington Drive
# 5          8940         Ridley Velez           280 Pennington Drive
# 6          2512        Devadas Sloan          8906 East John Street
# 7          1928       Jamaal Proctor                   374 New Lane
# 8          4524          Reba Morris             755 Hanover Street
# 9          9886        Nomusa Knight                            NaN
# 10         9815       Romaine Dunlap                  72 1st Street
# 11         7571         Regan Wilcox               55 Brewery Drive
# 12         1980        Forest Grimes       306 South Peninsula Road
# ...
